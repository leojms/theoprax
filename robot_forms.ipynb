# %% [markdown]
# ## Imports e Installs

# %%
#!pip install selenium

#instalar o pacote (tirar o comentario)

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

#baixar o webdriver para o chrome antes, verificar também a versão do seu navegador
#verificar a versão nos três pontinhos do chrome -> ajuda -> sobre o google chrome
#para instalar o driver: https://chromedriver.chromium.org/downloads
#após isso, colocar o arquivo do driver na pasta do anaconda3 que deve ficar em C:\Users\seu_usuario\Anaconda3
#se não usar o jupyter, colocar o arquivo do driver na pasta do python, que fica em C:\Users\seu_usuario\AppData\Local\Programs\Python\Python39

# %% [markdown]
# ## Código

# %% [markdown]
# ### Captação dos dados

# %%
#Utilizar o caminho exato de onde está salva a base de dados
#Não deixar o arquivo aberto quando rodar o código, caso contrário irá dar erro

u_senai = "leonardo.simoes"
u_note = "leona"
dados = pd.read_excel(fr"C:/Users/{u_note}/OneDrive - Sistema FIEB/General/Medição/db antiga/Concatenado_antigas.xlsx")
x= 207
dados = dados.iloc[x:222]
dados
# Out:
#      ID  Start time  Completion time  Email  Name  Pergunta    Nome  \
# 207 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 208 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 209 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 210 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 211 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 212 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 213 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 214 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 215 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 216 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 217 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 218 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# 219 NaN         NaN              NaN    NaN   NaN       NaN  Nalmir
# ...

# %% [markdown]
# ### Testes

# %%
#criação do objeto
navegador = webdriver.Chrome()

#link do formulário


for i in range(0, 4):
    navegador.get("https://forms.office.com/r/PAAurYRL2W")
    navegador.implicitly_wait(10)
    #Dados do operador
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys('Leonardo')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys('101')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input[1]').send_keys('01012022')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button/div').click()

    #Gerador 1
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys('10')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys('11')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys('12')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys('13')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Gerador 2
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys('20')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys('21')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys('22')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys('23')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Gerador 3
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys('30')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys('31')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys('32')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys('33')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Disjuntor rede Geral
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys('40')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys('41')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #QGBT-A e QGBT-B
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys('50')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys('51')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Coelba
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys('100')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys('101')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys('102')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys('103')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[6]/div/div[3]/div/div/input').send_keys('104')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[7]/div/div[3]/div/div/input').send_keys('105')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[8]/div/div[3]/div/div/input').send_keys('106')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[9]/div/div[3]/div/div/input').send_keys('107')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[10]/div/div[3]/div/div/input').send_keys('108')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[11]/div/div[3]/div/div/input').send_keys('109')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[12]/div/div[3]/div/div/input').send_keys('110')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[13]/div/div[3]/div/div/input').send_keys('111')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[14]/div/div[3]/div/div/input').send_keys('112')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[15]/div/div[3]/div/div/input').send_keys('113')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[16]/div/div[3]/div/div/input').send_keys('114')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[17]/div/div[3]/div/div/input').send_keys('115')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[18]/div/div[3]/div/div/input').send_keys('116')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[19]/div/div[3]/div/div/input').send_keys('117')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[20]/div/div[3]/div/div/input').send_keys('118')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[21]/div/div[3]/div/div/input').send_keys('119')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[22]/div/div[3]/div/div/input').send_keys('120')
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# c:\Users\leona\OneDrive - Sistema FIEB\General\robot_forms.ipynb Célula: 10 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/leona/OneDrive%20-%20Sistema%20FIEB/General/robot_forms.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> #link do formulário
#       <a href='vscode-notebook-cell:/c%3A/Users/leona/OneDrive%20-%20Sistema%20FIEB/General/robot_forms.ipynb#X11sZmlsZQ%3D%3D?line=6'>7</a> for i in range(0, 4):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/leona/OneDrive%20-%20Sistema%20FIEB/General/robot_forms.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a>     navegador.get("https://forms.office.com/r/PAAurYRL2W")
#       <a href='vscode-notebook-cell:/c%3A/Users/leona/OneDrive%20-%20Sistema%20FIEB/General/robot_forms.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>     navegador.implicitly_wait(10)
# ...

# %% [markdown]
# ### Robô

# %%
for i, data in enumerate(dados["Data da medição"], x):
    #Dados do operador
    matricula = int(dados.loc[i, "Matrícula"])
    nome = dados.loc[i, "Nome"]
    #Gerador 1
    run_abs_hs1 = int(dados.loc[i, "Run Absolute HS"])
    kwh1 = int(dados.loc[i, "Leitura kWh"])
    oleo1 = int(dados.loc[i, "Leitura consumo de óleo do gerador"])
    ope1 = int(dados.loc[i, "Número de operações"])
    #Gerador 2
    run_abs_hs2 = int(dados.loc[i, "Run Absolute HS3"])
    kwh2 = int(dados.loc[i, "Leitura kWh4"])
    oleo2 = int(dados.loc[i, "Leitura consumo de óleo do gerador5"])
    ope2 = int(dados.loc[i, "Número de operações6"])
    #Gerador 3
    run_abs_hs3 = int(dados.loc[i, "Run Absolute HS2"])
    kwh3 = int(dados.loc[i, "Leitura kWh2"])
    oleo3 = int(dados.loc[i, "Leitura consumo de óleo do gerador2"])
    ope3 = int(dados.loc[i, "Número de operações2"])
    #Disjuntor geral
    geral1 = int(dados.loc[i, "Leitura kWh42"])
    geral2 = int(dados.loc[i, "Número de operações do disjuntor"])
    #QGBT A e B
    qgbta = int(dados.loc[i, "Leitura QGBT-A"])
    qgbtb = int(dados.loc[i, "Leitura QGBT-B"])
    #Medidor Coelba
    reg3 = int(dados.loc[i, "Consumo ativo total"])
    reg4 = int(dados.loc[i, "Consumo ativo de ponta"])
    reg8 = int(dados.loc[i, "Consumo ativo fora de ponta"])
    reg10 = int(dados.loc[i, "Demanda ponta"])
    reg14 = int(dados.loc[i, "Demanda fora ponta"])
    reg17 = int(dados.loc[i, "Demanda de ponta acumulada"])
    reg21 = int(dados.loc[i, "Demanda fora de ponta acumulada"])
    reg24 = int(dados.loc[i, "Consumo reativo total"])
    reg25 = int(dados.loc[i, "Consumo reativo de ponta"])
    reg29 = int(dados.loc[i, "Consumo reativo fora de ponta"])
    reg34 = int(dados.loc[i, "D.M.P"])
    reg38 = int(dados.loc[i, "D.M.F"])
    reg52 = int(dados.loc[i, "Demanda máxima total"])    
    reg54 = int(dados.loc[i, "Demanda máxima acumulada"])
    reg65 = int(dados.loc[i, "Consumo reativo externo total"])
    reg66 = int(dados.loc[i, "Consumo reativo externo de ponta"])
    reg68 = int(dados.loc[i, "Consumo reativo externo fora de ponta"])
    reg69 = int(dados.loc[i, "Demanda média contratada rede de ponta"])
    reg71 = int(dados.loc[i, "Demanda média contratada rede fora de ponta"])
    reg73 = int(dados.loc[i, "Demanda média contratada rede acm. de ponta"])
    reg75 = int(dados.loc[i, "Demanda média contratada rede acm. fora de ponta ??"])
    
    data = list(str(datetime.date(data.to_pydatetime())))
    data = data[8]+data[9]+data[5]+data[6]+data[0]+data[1]+data[2]+data[3]
    
    #criação do objeto
    navegador = webdriver.Chrome()
    navegador.implicitly_wait(10)
    #link do formulário
    navegador.get("https://forms.office.com/r/PAAurYRL2W")

    #Dados do operador
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys(nome)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys(matricula)
    navegador.find_element(By.XPATH, '//*[@id="DatePicker0-label"]').send_keys(data)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button/div').click()

    #Gerador 1
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys(run_abs_hs1)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys(kwh1)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys(oleo1)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys(ope1)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Gerador 2
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys(run_abs_hs2)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys(kwh2)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys(oleo2)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys(ope2)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Gerador 3
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys(run_abs_hs3)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys(kwh3)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys(oleo3)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys(ope3)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Disjuntor rede Geral
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys(geral1)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys(geral2)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #QGBT-A e QGBT-B
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys(qgbta)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys(qgbtb)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

    #Coelba
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[2]/div/div[3]/div/div/input').send_keys(reg3)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[3]/div/div[3]/div/div/input').send_keys(reg4)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[4]/div/div[3]/div/div/input').send_keys(reg8)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[5]/div/div[3]/div/div/input').send_keys(reg10)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[6]/div/div[3]/div/div/input').send_keys(reg14)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[7]/div/div[3]/div/div/input').send_keys(reg17)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[8]/div/div[3]/div/div/input').send_keys(reg21)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[9]/div/div[3]/div/div/input').send_keys(reg24)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[10]/div/div[3]/div/div/input').send_keys(reg25)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[11]/div/div[3]/div/div/input').send_keys(reg29)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[12]/div/div[3]/div/div/input').send_keys(reg34)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[13]/div/div[3]/div/div/input').send_keys(reg38)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[14]/div/div[3]/div/div/input').send_keys(reg52)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[15]/div/div[3]/div/div/input').send_keys(reg54)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[16]/div/div[3]/div/div/input').send_keys(reg65)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[17]/div/div[3]/div/div/input').send_keys(reg66)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[18]/div/div[3]/div/div/input').send_keys(reg68)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[19]/div/div[3]/div/div/input').send_keys(reg69)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[20]/div/div[3]/div/div/input').send_keys(reg71)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[21]/div/div[3]/div/div/input').send_keys(reg73)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[2]/div[22]/div/div[3]/div/div/input').send_keys(reg75)
    navegador.find_element(By.XPATH, '//*[@id="form-main-content"]/div/div[1]/div[2]/div[3]/div[1]/button[2]/div').click()

# %%
i=173
matricula = int(dados.loc[i, "Matrícula"])

# %%
#data2 = list(str(datetime.date(data.to_pydatetime())))
#data3 = int(data2[8]+data2[9]+data2[5]+data2[6]+data2[0]+data2[1]+data2[2]+data2[3])
#data3

# %%
list(enumerate(range(5), 4))
# Out:
# [(4, 0), (5, 1), (6, 2), (7, 3), (8, 4)]

# %%
navegador = webdriver.Chrome()
navegador.implicitly_wait(10)
#link do formulário
navegador.get("https://forms.office.com/r/PAAurYRL2W")
